# %%
import requests
from bs4 import BeautifulSoup
import random
import time

# %%
def type_prop(p):
    try:
        place_type = p.find('span', class_='YhemCb').text
    except:
        try:
            place_type = p.find('div', class_='kpS1Ac').text
        except:
            print('ERROR: Couldn\'t find place type.')
            place_type = None 
    return place_type
    
def other_props(p):
    place_address = None
    other_attrib = {}
    
    try:
        for attrib in p.findAll('span', class_='LrzXr'):
            t = attrib.parent.find('span', class_='w8qArf').text.replace(': ','')

            if t == 'כתובת':
                place_address = attrib.text
            else:
                other_attrib[t] = attrib.text
    except:
        None

    return other_attrib, place_address

def events_prop(p):
    close_events = []
    classi = 'AxJnmb'
    sub_classi = 'PZPZlf'
    
    if p.findAll('a', class_='P7Vl4c') is not None:
        url = 'https://www.google.com{}'.format(p.find('a', class_='P7Vl4c')['href'])  
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
        response = requests.get(url, headers=headers)
        content = response.content
        soup = BeautifulSoup((content).decode('UTF-8'))
        
        classi = 'EDblX'
        sub_classi = 'h998We'
        p = soup.find('div', class_='appbar')
        
    try:
        for e in p.find('div', class_=classi).findAll('div', class_=sub_classi):
            try:
                day = e.find('div', class_='aXUuyd').text
            except: day = None
            try:
                hour = e.find('div', class_='HoEOQb').text
            except: hour = None
            try:
                title = e.find('div', class_='title').text
            except: title = None
            close_events.append({'Day': day, 'Hour': hour, 'Title': title})
            print('***', day, hour, title)
    except Exception as e:
        print(e)
        None

    return close_events

class Place:    
    def __init__(self, name):
        self.name = name
        
    def google_soup(self):
        url = 'https://www.google.com/search?q={}'.format(self.name.replace(' ','+'))  
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
        response = requests.get(url, headers=headers)
        content = response.content
        soup = BeautifulSoup((content).decode('UTF-8'))
        
        self.soup = soup
        return soup
    
    def knowledge_panel(self):
        if hasattr(self, 'soup') == False:
            self.google_soup()       
        panel = self.soup.find('div', class_='knowledge-panel')
        
        self.panel = panel
        return panel
    
   
    
    def set_props(self):
        if hasattr(self, 'panel') == False:
            self.knowledge_panel() 
        p = self.panel
        
        place_type = type_prop(p)
        
        try:
            place_descrip = p.find('div', class_='hb8SAc').text
        except:
            place_descrip = None
        
        other_attrib, place_address = other_props(p)
        
        close_events = events_prop(p)
        
        self.type = place_type
        self.description = place_descrip
        self.address = place_address
        self.other = other_attrib
        self.events = close_events

        return {'type': place_type, 'descrip': place_descrip}, other_attrib, close_events

# %%
url = 'https://www.google.com{}'.format(x.panel.find('a', class_='P7Vl4c')['href'])  
print(url)
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
response = requests.get(url, headers=headers)
content = response.content
soup = BeautifulSoup((content).decode('UTF-8'))

p = soup.find('div', class_='appbar')
# Out:
# https://www.google.com/search?q=%D7%90%D7%A7%D7%A1%D7%A4%D7%95+%D7%AA%D7%9C+%D7%90%D7%91%D7%99%D7%91+%D7%90%D7%99%D7%A8%D7%95%D7%A2%D7%99%D7%9D+%D7%A7%D7%A8%D7%95%D7%91%D7%99%D7%9D&stick=H4sIAAAAAAAAAOPgEOLUz9U3yDDNK85WQjC1VLOTrfRz8pMTSzLz8-AMq9KC5PzczLx0hdSy1LyS4kWsJtcnXF9-feH1JdenKlxfdX2OApA_8frM6xNBjJnXV1yfen0RkJ6rAFQF4oDk5gIABLOjZnYAAAA&sa=X&ved=2ahUKEwiw_4f8vvHlAhWdSBUIHdf8C68QMTAaegQIEhAK

# %%
x = place('גני התערוכה תל אביב')

# %%
x.set_props()
# Out:
# *** יום ג׳, 19 בנוב׳ 9:00 Timber Israel 2019
# *** יום ב׳, 25 בנוב׳ 9:00 Mind The Tech TLV
# *** יום ג׳, 26 בנוב׳ 10:00 תערוכת בייבילנד 2019
# *** יום ד׳, 27 בנוב׳ 8:00 Delegation from Ukraine to Israfood
# *** יום ד׳, 27 בנוב׳ 9:00 Digital.Health.Now. 2019- EcoSystem
# *** יום ב׳, 2 בדצמ׳ None Technology Tel Aviv
# *** יום ב׳, 2 בדצמ׳ 9:00 ועידת ישראל לתעשייה 2019
# *** יום ג׳, 3 בדצמ׳ None WATEC Israel 2019
# *** יום ג׳, 10 בדצמ׳ 8:30 IoT, Embedded Solution & Microprocessors 2019
# *** יום ב׳, 16 בדצמ׳ 9:00 נבחרת 24 – כיצד להפוך למנהיגים
# *** יום ד׳, 18 בדצמ׳ 9:00 DevOpsDays Tel Aviv 2019
# *** יום ב׳, 23 בדצמ׳ 16:00 חנוקטאן 2019
# *** יום ג׳, 14 בינו׳ None Motion & Control 2020
# *** יום ד׳, 22 בינו׳ None The Israel Convention Fair
# *** יום ג׳, 28 בינו׳ None Cyber Tech International Conference & Exhibition
# *** יום ב׳, 3 בפבר׳ None Cybertech 2020
# *** יום ב׳, 3 בפבר׳ 9:00 GopherCon Israel 2020
# *** יום ב׳, 10 בפבר׳ None Imtm 2020
# *** יום ג׳, 11 בפבר׳ 10:00 Imtm 2020
# ...

# %%
len(x.events)
# Out:
# 32

# %%
print(x.description)
# Out:
# תיאורהמרכז המסחרי דיזנגוף סנטר שוכן במפגש הרחובות דיזנגוף והמלך ג'ורג' בתל אביב, כמאתיים מטרים דרומית לכיכר צינה דיזנגוף. הקמת המרכז החלה ב-1972 והוא נפתח לציבור ב-1977. במרכז כ-400 חנויות, בהן מבקרים מדי יום כ-40,000 מבקרים. ויקיפדיה

# %%
x.__dict__
# Out:
# {'name': 'דיזינגוף סנטר', 'soup': <!DOCTYPE html>
# ...

# %%
s = time.time()
x.knowledge_panel()
print(time.time() - s)
# Out:
# 0.0029900074005126953

# %%
def get_soup(place):
    url = 'https://www.google.com/search?q={}'.format(place.replace(' ','+'))
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
    response = requests.get(url, headers=headers)
    content = response.content
    print(content)
    return BeautifulSoup(content)

# %%
soup = get_soup('דיזינג')
soup.find_all("div", class_= "P4cfIb")
# Out:
# b'<!doctype html><html dir="rtl" itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="iw"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title dir="rtl">\xd7\xaa\xd7\x97\xd7\xa0\xd7\xaa \xd7\xa8\xd7\x9b\xd7\x91\xd7\xaa \xd7\xa1\xd7\x91\xd7\x99\xd7\x93\xd7\x95\xd7\xa8 \xd7\x9e\xd7\xa8\xd7\x9b\xd7\x96 - \xd7\x97\xd7\x99\xd7\xa4\xd7\x95\xd7\xa9 \xd7\x91-Google</title><script nonce="pVwCYOE7Pj/cgru74+kd3A==">(function(){window.google={kEI:\'A5rKXa3oO4-DjLsPq-qcuAc\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_A5rKXa3oO4-DjLsPq-qcuAc\',kGL:\'IL\',kBL:\'HtyJ\'};google.sn=\'web\';google.kHL=\'iw\';google.jsfs=\'Ffpdje\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;retu
# ...

# %%
rhscol

# %%
place = 'תחנת רכבת השלום'

# https://www.google.com/search?safe=active&sxsrf=ACYBGNSDjyfH6iSLU9mujjbb7EvL5ICKlQ%3A1573564081565&ei=sa7KXfaaIqS01fAP__O3mAg&q=%D7%AA%D7%97%D7%A0%D7%AA+%D7%93%D7%9C%D7%A7+%D7%A4%D7%96+%D7%A0%D7%9E%D7%99%D7%A8&oq=%D7%AA%D7%97%D7%A0%D7%AA+%D7%93%D7%9C%D7%A7+%D7%A4%D7%96+%D7%A0%D7%9E%D7%99%D7%A8&gs_l=psy-ab.3..0i22i30l2j38.994709.998450..998594...1.4..0.140.1733.0j15......0....1..gws-wiz.......0i71j35i39j0i131j0j0i10i67j0i131i67j0i67.U_hnXR1vqxI&ved=0ahUKEwi2t_OA3-TlAhUkWhUIHf_5DYMQ4dUDCAs&uact=5
url = 'https://www.google.com/search?q={}'.format(place.replace(' ','+'))
print(url)
# headers = {'User-Agent': random.choice(l)}
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
response = requests.get(url, headers=headers)
content = response.content
#print(content)
#print(str(content).decode(encoding='UTF-8',errors='strict'))
# print('RIvEdf' in str(content))
# print(content)
print('שידור' in (content).decode('UTF-8'))
soup = BeautifulSoup((content).decode('UTF-8'))
# print(soup.findAll('span', class_='m63ztc')[1].parent.text)
print(BeautifulSoup(content).find('div', class_='knowledge-panel').find('span', class_='YhemCb'))
print(soup.find('div', class_='knowledge-panel').findAll('span', class_='m63ztc')[1].parent.text)
# Out:
# https://www.google.com/search?q=תחנת+רכבת+השלום
# True
# <span class="YhemCb">תחנת רכבת בתל אביב יפו</span>
# שידור חי: לא עמוס מדי

# %%
'שידור' in (content).decode('UTF-8')
# Out:
# True

# %%
'Not too busy' in (content).decode('UTF-8')
# Out:
# False

# %%
'https://www.google.com/search?safe=active&tbm=lcl&sxsrf=ACYBGNSjTGgXDdAmMbEcqmrtp4gdLZaN0A%3A1573993226362&ei=CjvRXcTUFc61sAeg44bYDg&q=%D7%AA%D7%97%D7%A0%D7%95%D7%AA+%D7%93%D7%9C%D7%A7+%D7%90%D7%A9%D7%93%D7%95%D7%93&oq=%D7%AA%D7%97%D7%A0%D7%95%D7%AA+%D7%93%D7%9C%D7%A7+%D7%90%D7%A9%D7%93%D7%95%D7%93&gs_l=psy-ab.3..0i10k1j0j0i22i30k1j0i22i10i30k1l4j0i22i30k1l3.507372.508285.0.508555.5.5.0.0.0.0.133.490.0j4.4.0....0...1c.1.64.psy-ab..1.4.488....0.yqAtEwLG0DE#rlfi=hd:;si:4228574644233400108,l,ChzXqteX16DXldeqINeT15zXpyDXkNep15PXldeTIgOIAQFaEwoR16rXl9eg15XXqiDXk9ec16c;mv:[[31.8368922,34.684973],[31.7621141,34.6376487]]'=='https://www.google.com/search?safe=active&tbm=lcl&sxsrf=ACYBGNSjTGgXDdAmMbEcqmrtp4gdLZaN0A%3A1573993226362&ei=CjvRXcTUFc61sAeg44bYDg&q=%D7%AA%D7%97%D7%A0%D7%95%D7%AA+%D7%93%D7%9C%D7%A7+%D7%90%D7%A9%D7%93%D7%95%D7%93&oq=%D7%AA%D7%97%D7%A0%D7%95%D7%AA+%D7%93%D7%9C%D7%A7+%D7%90%D7%A9%D7%93%D7%95%D7%93&gs_l=psy-ab.3..0i10k1j0j0i22i30k1j0i22i10i30k1l4j0i22i30k1l3.507372.508285.0.508555.5.5.0.0.0.0.133.490.0j4.4.0....0...1c.1.64.psy-ab..1.4.488....0.yqAtEwLG0DE#rlfi=hd:;si:15561541618230039700,l,ChzXqteX16DXldeqINeT15zXpyDXkNep15PXldeTIgOIAQFaEwoR16rXl9eg15XXqiDXk9ec16c;mv:[[31.8368922,34.684973],[31.7621141,34.6376487]]'
# Out:
# False

# %%
'ש' in str(str(content).encode(encoding='ascii',errors='strict'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-161-2332b0a157a3> in <module>
# ----> 1 'ש' in str(str(content).decode(encoding='ascii',errors='strict'))
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
content
# Out:
# b'<!doctype html><html dir="rtl" itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="iw"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title dir="rtl">\xd7\x93\xd7\x99\xd7\x96\xd7\x99\xd7\xa0\xd7\x92\xd7\x95\xd7\xa3 \xd7\xa1\xd7\xa0\xd7\x98\xd7\xa8 - \xd7\x97\xd7\x99\xd7\xa4\xd7\x95\xd7\xa9 \xd7\x91-Google</title><script nonce="y6ttQHC+G+bDgPclt7rifQ==">(function(){window.google={kEI:\'R8fKXe3IAdzlgweRo7WgDA\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_R8fKXe3IAdzlgweRo7WgDA\',kGL:\'IL\',kBL:\'HtyJ\'};google.sn=\'web\';google.kHL=\'iw\';google.jsfs=\'Ffpdje\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window
# ...

# %%
str(content)
# Out:
# 'b\'<!doctype html><html dir="rtl" lang="iw"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title dir="rtl">&#1514;&#1495;&#1504;&#1514; &#1491;&#1500;&#1511; &#1508;&#1494; &#1504;&#1502;&#1497;&#1512; - &#1495;&#1497;&#1508;&#1493;&#1513; &#1489;-Google</title><script nonce="gJjXkW1OK3fz0rLnqkorJQ==">(function(){var a=window.performance;window.start=(new Date).getTime();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,e=c.responseStart;if(e>d&&e<=window.start){window.start=e;b.wsrt=e-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};google.aft=function(f){f.setAttribute("data-iml",+new Date)};}).call(this);(function(){window.jsarwt=function(){return!1};}).call(this);(function(){var c=[],e=0;window.ping=function(b){-1==b.indexOf("&zx")&&(b+="&zx="+(new Date).getTime());var a=new Image,d=e++;c[d]=a;a.onerror=a.onload=a.onabort=function(){delete c[d]};a.src=b};})
# ...

# %%
response.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
url = 'http://www.useragentstring.com/pages/useragentstring.php?name=Chrome'
print(url)
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
content = response.content
print('שידור' in str(BeautifulSoup(content)))
# Out:
# http://www.useragentstring.com/pages/useragentstring.php?name=Chrome
# False

# %%
soup = BeautifulSoup(content)

# %%
l = []
for browser in ['Chrome', 'Firefox', 'Safari', 'Opera']:
    print(browser)
    url = 'http://www.useragentstring.com/pages/useragentstring.php?name={}'.format(browser)
    response = requests.get(url)
    content = response.content
    soup = BeautifulSoup(content)
    print(len(l))
    l += [a.text for a in soup.findAll('a') if a.text[0:7]=='Mozilla']
# Out:
# Chrome
# 0
# Firefox
# 843
# Safari
# 2861
# Opera
# 3438

# %%
l
# Out:
# ['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/44.0.2403.155 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2226.0 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 6.4; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2225.0 Safari/537.36',
# ...

# %%
l = []
for a in soup.findAll('a'):
    [a.text for a in soup.findAll('a')] if a.text[0:7]=='Mozilla']:
        l.append(a.text)

# %%
random.choice(l)
# Out:
# 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_6; en-US) AppleWebKit/534.18 (KHTML, like Gecko) Chrome/11.0.660.0 Safari/534.18'

# %%
'ש' in BeautifulSoup(content)
# Out:
# False

# %%
# Out:
# [<span class="DgOJ8 m63ztc z1asCe ubnhhf" style="height:14px;line-height:14px;width:14px"><svg focusable="false" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M16 11c1.66 0 2.99-1.34 2.99-3S17.66 5 16 5c-1.66 0-3 1.34-3 3s1.34 3 3 3zm-8 0c1.66 0 2.99-1.34 2.99-3S9.66 5 8 5C6.34 5 5 6.34 5 8s1.34 3 3 3zm0 2c-2.33 0-7 1.17-7 3.5V19h14v-2.5c0-2.33-4.67-3.5-7-3.5zm8 0c-.29 0-.62.02-.97.05 1.16.84 1.97 1.97 1.97 3.45V19h6v-2.5c0-2.33-4.67-3.5-7-3.5z"></path></svg></span>,
#  <span class="m63ztc"><span class="f4LWDe">שידור חי</span>:</span>]

# %%
str(x)
# Out:
# 'b\'<!doctype html><html dir="rtl" itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="iw"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title dir="rtl">\\xd7\\x93\\xd7\\x99\\xd7\\x96\\xd7\\x99\\xd7\\xa0\\xd7\\x92\\xd7\\x95\\xd7\\xa3 \\xd7\\xa1\\xd7\\xa0\\xd7\\x98\\xd7\\xa8 - \\xd7\\x97\\xd7\\x99\\xd7\\xa4\\xd7\\x95\\xd7\\xa9 \\xd7\\x91-Google</title><script nonce="5GQpYd8DsVWqmqPyaZLTOQ==">(function(){window.google={kEI:\\\'O4LKXc7kHtmh1fAP0OO5iA0\\\',kEXPI:\\\'31\\\',authuser:0,kscs:\\\'c9c918f0_O4LKXc7kHtmh1fAP0OO5iA0\\\',kGL:\\\'IL\\\',kBL:\\\'HtyJ\\\'};google.sn=\\\'web\\\';google.kHL=\\\'iw\\\';google.jsfs=\\\'Ffpdje\\\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));
# ...
