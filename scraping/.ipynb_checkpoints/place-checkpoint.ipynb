# %%
import requests
from bs4 import BeautifulSoup
import random
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
class Department:
    def __init__(self, name, city):
        self.name = name
        self.city = city
        self.places = []
    
    def google_soup(self):
        url = 'https://www.google.com/search?q={}'.format('+'.join([self.name, self.city]).replace(' ','+'))  
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
        response = requests.get(url, headers=headers)
        content = response.content
        soup = BeautifulSoup((content).decode('UTF-8'))
        
        return soup
    
    def places_list(self):
        soup = self.google_soup()      
        link = soup.find('a', class_='cMjHbjVt9AZ__button')['href']
        
        url = 'https://www.google.com{}'.format(link)  
        print(url)
#         headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
#         response = requests.get(url, headers=headers)
#         content = response.content
#         soup = BeautifulSoup((content).decode('UTF-8'))
        
#         self.list = listi
#         return listi
    
    
        
#     def set_places(self, limit=5):

# %%
x = Department('רכבות', 'תל אביב')

# %%
x.places_list()
# Out:
# https://www.google.com/search?q=%D7%A8%D7%9B%D7%91%D7%95%D7%AA+%D7%AA%D7%9C+%D7%90%D7%91%D7%99%D7%91&npsic=0&rflfq=1&rldoc=1&rlha=0&rllag=32069012,34791549,1779&tbm=lcl&sa=X&ved=2ahUKEwiMkpmpvfPlAhUhsaQKHfNBACwQjGp6BAgGEBY

# %%
cMjHbjVt9AZ__button

# %%
def type_prop(p):
    try:
        place_type = p.find('span', class_='YhemCb').text
    except:
        try:
            place_type = p.find('div', class_='kpS1Ac').text
        except:
            print('ERROR: Couldn\'t find place type.')
            place_type = None 
    return place_type
    
def other_props(p):
    place_address = None
    other_attrib = {}
    
    try:
        for attrib in p.findAll('span', class_='LrzXr'):
            t = attrib.parent.find('span', class_='w8qArf').text.replace(': ','')

            if t == 'כתובת':
                place_address = attrib.text
            else:
                other_attrib[t] = attrib.text
    except:
        None

    return other_attrib, place_address

def events_prop(p):
    close_events = []
    classi = 'AxJnmb'
    sub_classi = 'PZPZlf'
    
    if p.find('a', class_='P7Vl4c') is not None:
        url = 'https://www.google.com{}'.format(p.find('a', class_='P7Vl4c')['href'])  
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
        response = requests.get(url, headers=headers)
        content = response.content
        soup = BeautifulSoup((content).decode('UTF-8'))
        
        classi = 'EDblX'
        sub_classi = 'h998We'
        p = soup.find('div', class_='appbar')
        
    try:
        for e in p.find('div', class_=classi).findAll('div', class_=sub_classi):
            try:
                day = e.find('div', class_='aXUuyd').text
            except: day = None
            try:
                hour = e.find('div', class_='HoEOQb').text
            except: hour = None
            try:
                title = e.find('div', class_='title').text
            except: title = None
            close_events.append({'Day': day, 'Hour': hour, 'Title': title})
            print('***', day, hour, title)
    except Exception as e:
        None

    return close_events

def get_code_by_selenium(place, chrome_driver_location):
    chrome_driver_location = chrome_driver_location
    first_url = 'http://www.google.com'
    options = webdriver.ChromeOptions()
    options.add_experimental_option('prefs', {'intl.accept_languages': 'he'})
    driver = webdriver.Chrome(chrome_driver_location, chrome_options=options)
    
    #driver.minimize_window()
    driver.get(first_url)
    driver.find_element_by_name('q').clear()
    search = driver.find_element_by_name('q')
    search.send_keys(place)
    search.send_keys(Keys.RETURN)
    html_code = BeautifulSoup(driver.page_source, 'lxml')
    
    driver.close()
    return html_code
    

class Place:    
    def __init__(self, name):
        self.name = name
        
    def google_soup(self):
        url = 'https://www.google.com/search?q={}'.format(self.name.replace(' ','+'))  
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
        response = requests.get(url, headers=headers)
        content = response.content
        s = time.time()
        soup = BeautifulSoup((content).decode('UTF-8'))
        print(time.time() - s)
        self.soup = soup
        return soup
    
    def knowledge_panel(self):
        if hasattr(self, 'soup') == False:
            self.google_soup()       
        panel = self.soup.find('div', class_='knowledge-panel')
        
        self.panel = panel
        return panel
    
    def live_pop(self):
        if hasattr(self, 'panel') == False:
            self.knowledge_panel() 
        p = self.panel
        
        try:
            live_report = p.findAll('span', class_='m63ztc')[1].parent.text
            live_height = p.find('div', class_='ZQ55mf')['style']
        except:
            print('Couldn\'t find live property')
            live_report = None
            live_height = None
    
        return {'live_report': live_report, 'live_height': live_height}
    
    def set_general_hours(self):
        chrome_driver_location = r'..\chromedriver_win32\chromedriver'
        soup = get_code_by_selenium(self.name, chrome_driver_location)
        
        week_dicti = {}
        for histo in soup.findAll('div', class_='ecodF'):
            day = histo['aria-label']
            day_dicti = {}
            for hour_ele in histo.findAll('div', class_='lubh-bar'):
                hour = hour_ele['aria-label'].split()[0]
                day_dicti[hour] = {'general_population': hour_ele['aria-label'], 'height': hour_ele['style']}
            week_dicti[day] = day_dicti

        self.general_population = week_dicti
        return week_dicti
    
    def set_props(self):
        if hasattr(self, 'panel') == False:
            self.knowledge_panel() 
        p = self.panel
        
        place_type = type_prop(p)
        
        try:
            place_descrip = p.find('div', class_='hb8SAc').text
        except:
            place_descrip = None
        
        other_attrib, place_address = other_props(p)
        
        close_events = events_prop(p)
        
        live_population = self.live_pop(p)
                
        self.type = place_type
        self.description = place_descrip
        self.address = place_address
        self.other = other_attrib
        self.events = close_events
        self.live_population = live_population
        
        return {'type': place_type, 'descrip': place_descrip}, other_attrib, close_events

# %%
len(x.panel.findAll('div', class_='ecodF'))
# Out:
# 1

# %%
x.set_general_hours()
# Out:
# c:\users\alony\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:68: DeprecationWarning: use options instead of chrome_options
# {'היסטוגרמה המראה שעות פופולריות בימי ראשון': {'9:00:': {'general_population': '9:00: בדרך כלל לא עמוס',
#    'height': 'height: 11px;'},
#   '10:00:': {'general_population': '10:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 21px;'},
#   '11:00:': {'general_population': '11:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 33px;'},
#   '12:00:': {'general_population': '12:00: בדרך כלל עמוס קצת',
#    'height': 'height: 41px;'},
#   '13:00:': {'general_population': '13:00: בדרך כלל עמוס קצת',
#    'height': 'height: 42px;'},
#   '14:00:': {'general_population': '14:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 36px;'},
#   '15:00:': {'general_population': '15:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 29px;'},
#   '16:00:': {'general_population': '16:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 26px;'},
#   '17:00:': {'general_population': '17:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 26px;'},
#   '18:00:': {'general_population': '18:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 26px;'},
#   '19:00:': {'general_population': '19:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 24px;'},
#   '20:00:': {'general_population': '20:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 19px;'},
#   '21:00:': {'general_population': '21:00: בדרך כלל לא עמוס',
#    'height': 'height: 11px;'}},
#  'היסטוגרמה המראה שעות פופולריות בימי שני': {'9:00:': {'general_population': '9:00: בדרך כלל לא עמוס',
#    'height': 'height:6px'},
#   '10:00:': {'general_population': '10:00: בדרך כלל לא עמוס',
#    'height': 'height:12px'},
#   '11:00:': {'general_population': '11:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:18px'},
#   '12:00:': {'general_population': '12:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:22px'},
#   '13:00:': {'general_population': '13:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:24px'},
#   '14:00:': {'general_population': '14:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:24px'},
#   '15:00:': {'general_population': '15:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:24px'},
#   '16:00:': {'general_population': '16:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:24px'},
#   '17:00:': {'general_population': '17:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:27px'},
#   '18:00:': {'general_population': '18:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:28px'},
#   '19:00:': {'general_population': '19:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:27px'},
#   '20:00:': {'general_population': '20:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:23px'},
#   '21:00:': {'general_population': '21:00: בדרך כלל לא עמוס מדי',
#    'height': 'height:16px'}},
#  'היסטוגרמה המראה שעות פופולריות בימי שלישי': {'9:00:': {'general_population': '9:00: בדרך כלל לא עמוס',
#    'height': 'height: 9px;'},
#   '10:00:': {'general_population': '10:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 19px;'},
#   '11:00:': {'general_population': '11:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 29px;'},
#   '12:00:': {'general_population': '12:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 37px;'},
#   '13:00:': {'general_population': '13:00: בדרך כלל עמוס קצת',
#    'height': 'height: 39px;'},
#   '14:00:': {'general_population': '14:00: בדרך כלל עמוס קצת',
#    'height': 'height: 38px;'},
#   '15:00:': {'general_population': '15:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 36px;'},
#   '16:00:': {'general_population': '16:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 36px;'},
#   '17:00:': {'general_population': '17:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 36px;'},
#   '18:00:': {'general_population': '18:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 35px;'},
#   '19:00:': {'general_population': '19:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 33px;'},
#   '20:00:': {'general_population': '20:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 26px;'},
#   '21:00:': {'general_population': '21:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 18px;'}},
#  'היסטוגרמה המראה שעות פופולריות בימי רביעי': {'9:00:': {'general_population': '9:00: בדרך כלל לא עמוס',
#    'height': 'height: 8px;'},
#   '10:00:': {'general_population': '10:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 15px;'},
#   '11:00:': {'general_population': '11:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 23px;'},
#   '12:00:': {'general_population': '12:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 29px;'},
#   '13:00:': {'general_population': '13:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 32px;'},
#   '14:00:': {'general_population': '14:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 32px;'},
#   '15:00:': {'general_population': '15:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 31px;'},
#   '16:00:': {'general_population': '16:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 32px;'},
#   '17:00:': {'general_population': '17:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 34px;'},
#   '18:00:': {'general_population': '18:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 35px;'},
#   '19:00:': {'general_population': '19:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 32px;'},
#   '20:00:': {'general_population': '20:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 26px;'},
#   '21:00:': {'general_population': '21:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 17px;'}},
#  'היסטוגרמה המראה שעות פופולריות בימי חמישי': {'9:00:': {'general_population': '9:00: בדרך כלל לא עמוס',
#    'height': 'height: 9px;'},
#   '10:00:': {'general_population': '10:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 17px;'},
#   '11:00:': {'general_population': '11:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 26px;'},
#   '12:00:': {'general_population': '12:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 34px;'},
#   '13:00:': {'general_population': '13:00: בדרך כלל עמוס קצת',
#    'height': 'height: 38px;'},
#   '14:00:': {'general_population': '14:00: בדרך כלל עמוס קצת',
#    'height': 'height: 38px;'},
#   '15:00:': {'general_population': '15:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 36px;'},
#   '16:00:': {'general_population': '16:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 37px;'},
#   '17:00:': {'general_population': '17:00: בדרך כלל עמוס קצת',
#    'height': 'height: 38px;'},
#   '18:00:': {'general_population': '18:00: בדרך כלל עמוס קצת',
#    'height': 'height: 39px;'},
#   '19:00:': {'general_population': '19:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 35px;'},
#   '20:00:': {'general_population': '20:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 29px;'},
#   '21:00:': {'general_population': '21:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 20px;'}},
#  'היסטוגרמה המראה שעות פופולריות בימי שישי': {'9:00:': {'general_population': '9:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 17px;'},
#   '10:00:': {'general_population': '10:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 35px;'},
#   '11:00:': {'general_population': '11:00: בדרך כלל עמוס קצת',
#    'height': 'height: 57px;'},
#   '12:00:': {'general_population': '12:00: בדרך כלל שיא העומס של המקום',
#    'height': 'height: 74px;'},
#   '13:00:': {'general_population': '13:00: בדרך כלל שיא העומס של המקום',
#    'height': 'height: 75px;'},
#   '14:00:': {'general_population': '14:00: בדרך כלל שיא העומס של המקום',
#    'height': 'height: 60px;'}},
#  'היסטוגרמה המראה שעות פופולריות בשבתות': {'20:00:': {'general_population': '20:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 16px;'},
#   '21:00:': {'general_population': '21:00: בדרך כלל לא עמוס מדי',
#    'height': 'height: 17px;'},
#   '22:00:': {'general_population': '22:00: בדרך כלל לא עמוס',
#    'height': 'height: 13px;'}}}

# %%
x = Place('דיזינגוף סנטר')

# %%
ss = time.time()
x.live_pop()
print(time.time() - ss)
# Out:
# 0.02790999412536621
# 0.8529746532440186

# %%
x.set_props()
# Out:
# *** יום ג׳, 19 בנוב׳ 19:00 החיידק שהציל אותי: שיחה עם פרופ' ערן סגל ממכון ויצמן למדע
# *** יום ג׳, 3 בדצמ׳ 21:00 ״לכטוב״ // בית הספר לכתיבה יוצרת בדיזנגוף סנטר // ההשקה!
# *** יום ה׳, 26 בדצמ׳ 10:00 הרפתקון: חנוכה
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-26f373baf6c0> in <module>
# ----> 1 x.set_props()
#
# <ipython-input-172-7be6f757febe> in set_props(self)
#     149         close_events = events_prop(p)
#     150
# --> 151         live_population = self.live_pop(p)
#     152
#     153         self.type = place_type
#
# TypeError: live_pop() takes 1 positional argument but 2 were given

# %%
url = 'https://www.google.com/search?q={}'.format('דיזינגוף')  
# headers = {'USER-AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'}
# headers['Accept'] = 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3'

response = requests.get(url, headers=headers)
# print(response.headers)
content = response.content
soup = BeautifulSoup((content).decode('UTF-8'))
len(soup.findAll('div', class_='ecodF'))
# Out:
# 1

# %%
dict(response.request.headers)
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36',
#  'Accept-Encoding': 'gzip, deflate',
#  'Accept': '*/*',
#  'Connection': 'keep-alive'}

# %%
requests.headers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-195-d885c4e574fd> in <module>
# ----> 1 requests.headers
#
# AttributeError: module 'requests' has no attribute 'headers'
